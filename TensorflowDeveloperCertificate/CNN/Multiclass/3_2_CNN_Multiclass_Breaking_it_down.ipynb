# %%
#Import modules
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, Flatten, Conv2D, MaxPool2D
from tensorflow.keras.optimizers import Adam

import pathlib
import os
import random
import zipfile

# %% [markdown]
# # data link
#
# https://storage.googleapis.com/ztm_tf_course/food_vision/10_food_classes_all_data.zip

# %%
# Download and extract the data

# !wget https://storage.googleapis.com/ztm_tf_course/food_vision/10_food_classes_all_data.zip

#Uzip the downloaded data
zip_ref = zipfile.ZipFile("10_food_classes_all_data.zip", "r")
zip_ref.extractall()
zip_ref.close()
# Out:
# --2024-11-08 16:27:29--  https://storage.googleapis.com/ztm_tf_course/food_vision/10_food_classes_all_data.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.122.207, 172.253.63.207, 142.250.31.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.122.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 519183241 (495M) [application/zip]
# Saving to: ‘10_food_classes_all_data.zip’
#
# 10_food_classes_all 100%[===================>] 495.13M   178MB/s    in 2.8s
#
# 2024-11-08 16:27:32 (178 MB/s) - ‘10_food_classes_all_data.zip’ saved [519183241/519183241]

# %%
# Walk throug the 10 different classed of image data downloaded
for dirpath, dirnames, filenames in os.walk("10_food_classes_all_data"):
  print(f"There are {len(dirnames)} directories with {len(filenames)} files in directory {dirpath}")
# Out:
# There are 2 directories with 0 files in directory 10_food_classes_all_data
# There are 10 directories with 0 files in directory 10_food_classes_all_data/train
# There are 0 directories with 750 files in directory 10_food_classes_all_data/train/chicken_curry
# There are 0 directories with 750 files in directory 10_food_classes_all_data/train/pizza
# There are 0 directories with 750 files in directory 10_food_classes_all_data/train/ice_cream
# There are 0 directories with 750 files in directory 10_food_classes_all_data/train/chicken_wings
# There are 0 directories with 750 files in directory 10_food_classes_all_data/train/fried_rice
# There are 0 directories with 750 files in directory 10_food_classes_all_data/train/steak
# There are 0 directories with 750 files in directory 10_food_classes_all_data/train/grilled_salmon
# There are 0 directories with 750 files in directory 10_food_classes_all_data/train/sushi
# ...

# %%
# Setup train and test directories
train_dir = "10_food_classes_all_data/train/"
test_dir = "10_food_classes_all_data/test/"

# %%
def view_random_image(target_dir, target_class):
    # setup target directory
    target_folder = target_dir + target_class

    #Get one random image from target folder
    random_image = random.sample(os.listdir(target_folder), 1)

    #Read image and plor using matplot
    img = mpimg.imread(target_folder + "/" + random_image[0])
    plt.imshow(img)
    plt.title(target_class)
    plt.axis("off")

    print(f"Image shape {img.shape}") # show shape of the image
    return img

# %%
# Get the classnames from the dataset
import pathlib
data_dir = pathlib.Path(train_dir)
class_names = np.array(sorted([item.name for item in data_dir.glob('*')]))
print(class_names)
# Out:
# ['chicken_curry' 'chicken_wings' 'fried_rice' 'grilled_salmon' 'hamburger'
#  'ice_cream' 'pizza' 'ramen' 'steak' 'sushi']

# %%
img = view_random_image(target_dir=train_dir, target_class=random.choice(class_names))
# Out:
# Image shape (382, 512, 3)

# %%
# Preprocess the data

#Rescla the images
train_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)

# Turn data into batches
train_data = train_datagen.flow_from_directory(train_dir,
                                               target_size=(224,224),
                                               batch_size=32,
                                               class_mode='categorical',
                                               )


test_data = test_datagen.flow_from_directory(test_dir,
                                             target_size=(224,224),
                                             batch_size=32,
                                             class_mode='categorical',
                                            )


# Convert the ImageDataGenerator to a tf.data.Dataset
train_dataset = tf.data.Dataset.from_generator(
    lambda: train_data,
    output_signature=(
        tf.TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32),  # Adjust shape for your data
        tf.TensorSpec(shape=(None,10), dtype=tf.int32)  # Adjust for categorical labels
    )
)

test_dataset = tf.data.Dataset.from_generator(
    lambda: test_data,
    output_signature=(
        tf.TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(None,10), dtype=tf.int32)
    )
)
# Out:
# Found 7500 images belonging to 10 classes.
# Found 2500 images belonging to 10 classes.

# %%
import math
# Get number of samples in train and test dir

# Repeat the datasets for multiple epochs
train_dataset = train_dataset.repeat()
test_dataset = test_dataset.repeat()

# Prefetch to improve performance (optional)
train_dataset = train_dataset.prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.prefetch(tf.data.AUTOTUNE)

# Calculate steps per epoch
train_steps_per_epoch = len(train_data)  # Equivalent to train_data.samples // batch_size
validation_steps_per_epoch = len(test_data)  # Equivalent to test_data.samples // batch_size

# %%
train_steps_per_epoch / 32
# Out:
# 7.3125

# %%
# Create the model

model_1 = Sequential([
    Input(shape=(224,224,3)),
    Conv2D(10, 3, activation='relu'),
    Conv2D(10, 3, activation='relu'),
    MaxPool2D(),
    Conv2D(10, 3, activation='relu'),
    Conv2D(10, 3, activation='relu'),
    MaxPool2D(),
    Flatten(),
    Dense(10, activation='softmax')

])

# Compile the model
model_1.compile(loss='categorical_crossentropy',
                optimizer=Adam(),
                metrics=['accuracy'])

# %%
# Fit the model
history_1 = model_1.fit(train_dataset,
                        epochs=5,
                        steps_per_epoch=train_steps_per_epoch,
                        validation_data=test_dataset,
                        validation_steps=validation_steps_per_epoch
                        )
# Out:
# Epoch 1/5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 563s 2s/step - accuracy: 0.1824 - loss: 2.2247 - val_accuracy: 0.2984 - val_loss: 1.9919
# Epoch 2/5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 548s 2s/step - accuracy: 0.3382 - loss: 1.9222 - val_accuracy: 0.3304 - val_loss: 1.9171
# Epoch 3/5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 519s 2s/step - accuracy: 0.4844 - loss: 1.5598 - val_accuracy: 0.3348 - val_loss: 1.9526
# Epoch 4/5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 505s 2s/step - accuracy: 0.7335 - loss: 0.8666 - val_accuracy: 0.2908 - val_loss: 2.4562
# Epoch 5/5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 504s 2s/step - accuracy: 0.9080 - loss: 0.3201 - val_accuracy: 0.2768 - val_loss: 3.4101

# %%
# Plot training and validation curve seperately
def plot_loss_curve(history):
  '''
  Returns separate loss curves for training and validation metrics.
  '''
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epoches = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epoches, loss, label='training_loss')
  plt.plot(epoches, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()


  # Plot accuracy
  plt.figure() ## Everytime want to create a new figure use it
  plt.plot(epoches, accuracy, label='training_accuracy')
  plt.plot(epoches, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()

# %%
model_1.evaluate(test_data)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.3197 - loss: 2.1487
# [2.1360301971435547, 0.3100000023841858]

# %%
plot_loss_curve(history_1)

# training loss goign down - learning the training data very well but not geenraliging unseen data

# %% [markdown]
# # Adjust hyper parameters and reduce overfitting
#
# * **Get more data**
# * **Simplify the model**
# * **Reduce data augmentaion**
# * **Use transfered learining**

# %%
model_2 = Sequential([
    Input(shape=(224,224,3)),
    Conv2D(10, 3, activation='relu'),
    MaxPool2D(),
    Conv2D(10, 3, activation='relu'),
    MaxPool2D(),
    Flatten(),
    Dense(10, activation='softmax')
])

model_2.compile(loss='categorical_crossentropy',
                optimizer=Adam(),
                metrics=['accuracy'])

history_2 = model_2.fit(
    train_data.repeat(),
    epochs=5,
    steps_per_epoch=train_steps_per_epoch,
    validation_data=test_data,
    validation_steps=validation_steps_per_epoch
)
# Out:
# Epoch 1/5
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 29s 111ms/step - accuracy: 0.2042 - loss: 2.3254 - val_accuracy: 0.3277 - val_loss: 1.9058
# Epoch 2/5
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4062 - loss: 1.7807 - val_accuracy: 0.7500 - val_loss: 1.8884
# Epoch 3/5
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 38s 105ms/step - accuracy: 0.3844 - loss: 1.7757 - val_accuracy: 0.3301 - val_loss: 1.8885
# Epoch 4/5
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.4062 - loss: 1.5624 - val_accuracy: 0.5000 - val_loss: 1.5922
# Epoch 5/5
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 26s 107ms/step - accuracy: 0.5460 - loss: 1.3753 - val_accuracy: 0.3345 - val_loss: 1.9847

# %%
model_2.summary()
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_31 (Conv2D)                   │ (None, 222, 222, 10)        │             280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_24 (MaxPooling2D)      │ (None, 111, 111, 10)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_32 (Conv2D)                   │ (None, 109, 109, 10)        │             910 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_25 (MaxPooling2D)      │ (None, 54, 54, 10)          │               0 │
# ...

# %%
model_1.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_27 (Conv2D)                   │ (None, 222, 222, 10)        │             280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_28 (Conv2D)                   │ (None, 220, 220, 10)        │             910 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_22 (MaxPooling2D)      │ (None, 110, 110, 10)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_29 (Conv2D)                   │ (None, 108, 108, 10)        │             910 │
# ...

# %%
plot_loss_curve(history_2)

# %% [markdown]
# # Reduce overfitting using data augmentation

# %%
# Augmented data generator
train_datagen_augmented = ImageDataGenerator(rescale=1/255.,
                                          rotation_range=0.2,
                                          width_shift_range=0.2,
                                          height_shift_range=0.2,
                                          zoom_range=0.2,
                                          horizontal_flip=True)

train_data_augmented = train_datagen_augmented.flow_from_directory(
                                          train_dir,
                                          target_size=(224,224),
                                          batch_size=32,
                                          class_mode='categorical'
                                      )


# test_data_augmented = ImageDataGenerator(rescale=1/255.)


# Convert the ImageDataGenerator to a tf.data.Dataset

train_augmented_dataset = tf.data.Dataset.from_generator(
    lambda: train_data_augmented,
    output_signature=(
        tf.TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32),  # Adjust shape for your data
        tf.TensorSpec(shape=(None,10), dtype=tf.int32)  # Adjust for categorical labels
    )
)


# Repeat the datasets for multiple epochs
train_augmented_dataset = train_augmented_dataset.repeat()
test_dataset = test_dataset.repeat()

# Prefetch to improve performance (optional)
train_augmented_dataset = train_augmented_dataset.prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.prefetch(tf.data.AUTOTUNE)

# Calculate steps per epoch
train_steps_per_epoch = len(train_data_augmented)  # Equivalent to train_data.samples // batch_size
validation_steps_per_epoch = len(test_data)  # Equivalent to test_data.samples // batch_size
# Out:
# Found 7500 images belonging to 10 classes.

# %%
# Clone model1
model_3 = tf.keras.models.clone_model(model_1)

#Compile the model
model_3.compile(loss='categorical_crossentropy',
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['accuracy'])


# fit the model
hostiry_3 = model_3.fit(train_augmented_dataset,
                        epochs=5,
                        steps_per_epoch=train_steps_per_epoch,
                        validation_data = test_dataset,
                        validation_steps = validation_steps_per_epoch
                        )
# Out:
# Epoch 1/5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 447ms/step - accuracy: 0.1499 - loss: 2.2895 - val_accuracy: 0.2792 - val_loss: 1.9824
# Epoch 2/5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 101s 431ms/step - accuracy: 0.2571 - loss: 2.0804 - val_accuracy: 0.3108 - val_loss: 1.9798
# Epoch 3/5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 99s 423ms/step - accuracy: 0.2932 - loss: 2.0153 - val_accuracy: 0.3664 - val_loss: 1.8339
# Epoch 4/5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 100s 425ms/step - accuracy: 0.3287 - loss: 1.9455 - val_accuracy: 0.3736 - val_loss: 1.8118
# Epoch 5/5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 101s 429ms/step - accuracy: 0.3568 - loss: 1.8887 - val_accuracy: 0.4080 - val_loss: 1.7521

# %%
model_3.evaluate(test_data)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - accuracy: 0.3104 - loss: 1.9508
# [1.9479739665985107, 0.3019999861717224]

# %%
model_1.evaluate(test_data)

# %%
plot_loss_curve(hostiry_3)
